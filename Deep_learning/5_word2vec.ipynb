# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.738033
# Nearest to five: characteristic, serif, hilly, retitled, diving, keflav, watching, englishman,
# Nearest to on: enola, unchecked, changes, leave, surpass, fa, nightmares, binomial,
# Nearest to years: expulsions, nuncio, influences, marques, charlemagne, thirties, locales, tnt,
# Nearest to see: sound, backronym, laugh, pious, turbofans, percentages, rumsfeld, periods,
# Nearest to was: llama, licensure, brahmins, stine, metastasis, cor, adequacy, rheumatism,
# Nearest to who: masterpiece, laban, descendents, aneurin, watt, simply, sequestration, faye,
# Nearest to history: canopus, presuppose, trolls, gutnish, anthroposophical, yacc, cordon, herbivore,
# Nearest to zero: amplifier, encapsulation, danann, infocom, condenses, recreationally, innovation, tito,
# Nearest to these: journalism, annum, backgrounds, mercenary, assistants, autonomist, biathletes, mujahidin,
# Nearest to more: monody, jespersen, haitian, dragon, skew, montauban, panentheism, ateneo,
# Nearest to seven: las, psychology, stative, marko, withhold, price, robustus, sown,
# Nearest to one: endomorphism, responsa, fourths, consortium, became, expectation, hays, coins,
# Nearest to i: aligned, oxidising, unconfirmed, exmoor, ibf, rodman, slingshot, carmilla,
# Nearest to four: sylheti, carom, xv, benzoate, mentioning, gottlob, delaying, restricted,
# Nearest to are: desylva, fired, robbers, duc, annihilate, humanitarian, fields, epistemology,
# Nearest to eight: aryans, seater, wonderful, bsa, cetacea, conjectured, commanding, volcano,
# Average loss at step 2000: 4.409607
# Average loss at step 4000: 3.857882
# Average loss at step 6000: 3.654785
# Average loss at step 8000: 3.524451
# Average loss at step 10000: 3.665116
# Nearest to five: eight, seven, four, six, three, nine, two, zero,
# Nearest to on: in, determinant, binomial, reconstituted, for, fa, against, thor,
# Nearest to years: year, pickups, zout, nuncio, clyde, msf, bit, daedalus,
# Nearest to see: arcology, nina, tasman, brothers, cytoplasmic, extraordinarily, sound, guadalcanal,
# Nearest to was: is, has, had, were, by, are, been, became,
# Nearest to who: he, been, scraped, aggadah, descendents, arleigh, sequestration, detected,
# Nearest to history: canopus, olds, fujitsu, presuppose, herbivore, transforming, goodyear, yacc,
# Nearest to zero: four, five, seven, six, nine, eight, three, two,
# Nearest to these: annum, miao, backgrounds, many, instead, actors, nullify, kazantzakis,
# Nearest to more: montauban, less, mechanical, sabina, monody, served, extensively, skynyrd,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to one: two, three, eight, six, four, five, nine, seven,
# Nearest to i: we, aligned, gropius, carmilla, doctors, reproduction, oxidising, stipulations,
# Nearest to four: five, six, seven, three, eight, zero, two, nine,
# Nearest to are: were, is, have, was, satrapy, gropius, accede, other,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Average loss at step 12000: 3.611491
# Average loss at step 14000: 3.558262
# Average loss at step 16000: 3.555614
# Average loss at step 18000: 3.583093
# Average loss at step 20000: 3.505790
# Nearest to five: three, six, zero, eight, seven, four, nine, two,
# Nearest to on: in, at, with, from, for, after, determinant, by,
# Nearest to years: year, pickups, days, nuncio, veracruz, zout, lh, clyde,
# Nearest to see: nina, cytoplasmic, ot, tasman, heinkel, arcology, unanswered, taylor,
# Nearest to was: is, were, had, has, been, became, acquisitions, be,
# Nearest to who: he, which, cooke, they, scraped, detected, aggadah, arleigh,
# Nearest to history: fujitsu, olds, list, canopus, presuppose, fragrant, accuracy, roch,
# Nearest to zero: five, six, three, four, eight, seven, nine, two,
# Nearest to these: many, some, which, instead, all, doubtless, they, those,
# Nearest to more: less, mechanical, very, montauban, sabina, most, fright, hearted,
# Nearest to seven: nine, six, eight, five, four, three, zero, two,
# Nearest to one: two, eight, three, four, six, nine, five, seven,
# Nearest to i: we, t, ii, doctors, o, reproduction, catalogs, gropius,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to are: were, is, have, gropius, other, kilowatts, soaked, these,
# Nearest to eight: six, nine, seven, five, three, four, two, zero,
# Average loss at step 22000: 3.593184
# Average loss at step 24000: 3.520520
# Average loss at step 26000: 3.535613
# Average loss at step 28000: 3.336693
# Average loss at step 30000: 3.510011
# Nearest to five: six, seven, four, three, eight, zero, two, nine,
# Nearest to on: upon, silicates, determinant, eyewitnesses, fewest, in, impartial, constellation,
# Nearest to years: days, year, veracruz, pickups, nuncio, zout, desktop, neuroscientist,
# Nearest to see: nina, ot, heinkel, cytoplasmic, dissolve, but, arcology, unanswered,
# Nearest to was: is, were, has, had, became, been, after, be,
# Nearest to who: which, he, and, they, arleigh, aggadah, that, detected,
# Nearest to history: list, fujitsu, accuracy, dogme, neighboring, olds, russell, landing,
# Nearest to zero: five, four, six, seven, eight, nine, two, three,
# Nearest to these: some, many, such, they, are, all, different, those,
# Nearest to more: less, most, very, mechanical, fright, sabina, montauban, skynyrd,
# Nearest to seven: six, eight, four, five, three, nine, two, one,
# Nearest to one: two, eight, seven, four, six, three, five, nine,
# Nearest to i: ii, we, t, you, he, doctors, reproduction, accuses,
# Nearest to four: eight, six, seven, five, three, nine, two, zero,
# Nearest to are: were, have, is, these, tentatively, those, do, gropius,
# Nearest to eight: four, nine, six, seven, five, three, one, two,
# Average loss at step 32000: 3.460338
# Average loss at step 34000: 3.469817
# Average loss at step 36000: 3.474050
# Average loss at step 38000: 3.436587
# Average loss at step 40000: 3.412472
# Nearest to five: four, six, eight, seven, three, nine, zero, one,
# Nearest to on: in, upon, determinant, through, from, at, silicates, overthrowing,
# Nearest to years: days, year, months, pickups, scattering, people, paths, desktop,
# Nearest to see: combo, heinkel, fevers, js, dictator, nina, dissolve, arcology,
# Nearest to was: is, were, has, had, became, been, correctness, makes,
# Nearest to who: he, which, contraceptives, they, cooke, aggadah, also, but,
# Nearest to history: list, accuracy, fujitsu, conses, dogme, populous, chase, neighboring,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to these: some, many, such, those, they, both, are, instead,
# Nearest to more: less, most, very, mechanical, hearted, fright, beckenbauer, skynyrd,
# Nearest to seven: eight, four, six, five, nine, three, zero, one,
# Nearest to one: eight, two, four, six, seven, nine, five, three,
# Nearest to i: we, ii, you, t, accuses, he, they, n,
# Nearest to four: five, six, three, eight, seven, nine, two, one,
# Nearest to are: were, have, is, these, do, adage, although, be,
# Nearest to eight: nine, six, seven, four, five, three, one, zero,
# Average loss at step 42000: 3.403764
# Average loss at step 44000: 3.445626
# Average loss at step 46000: 3.466070
# Average loss at step 48000: 3.434808
# Average loss at step 50000: 3.437750
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Nearest to on: upon, in, determinant, silicates, thor, through, enola, after,
# Nearest to years: days, year, months, people, hours, pickups, scattering, million,
# Nearest to see: can, but, include, combo, heinkel, fevers, cytoplasmic, ot,
# Nearest to was: is, became, were, had, has, be, although, been,
# Nearest to who: he, which, contraceptives, arleigh, they, there, cooke, young,
# Nearest to history: list, accuracy, fujitsu, philosophy, gospel, allosaurus, conses, dictionary,
# Nearest to zero: five, seven, six, four, eight, nine, two, three,
# Nearest to these: many, some, those, such, all, various, they, both,
# Nearest to more: less, very, most, mechanical, rather, too, hearted, offensively,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to one: six, two, four, five, eight, three, nine, seven,
# Nearest to i: ii, we, you, t, accuses, g, ll, doctors,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to are: were, have, is, but, be, these, adage, gropius,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Average loss at step 52000: 3.386393
# Average loss at step 54000: 3.150172
# Average loss at step 56000: 3.420879
# Average loss at step 58000: 3.413661
# Average loss at step 60000: 3.369159
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to on: upon, through, in, under, determinant, at, about, before,
# Nearest to years: days, months, year, hours, decades, scattering, tests, weeks,
# Nearest to see: include, cronje, but, ot, borrower, sportsman, heinkel, dissolve,
# Nearest to was: is, has, had, became, were, been, by, be,
# Nearest to who: they, which, he, arleigh, contraceptives, that, aggadah, there,
# Nearest to history: list, accuracy, conses, allosaurus, populous, mornings, fragrant, philosophy,
# Nearest to zero: five, six, four, eight, seven, three, two, nine,
# Nearest to these: many, some, those, various, such, several, which, they,
# Nearest to more: less, most, very, rather, smaller, too, hearted, larger,
# Nearest to seven: six, four, eight, nine, five, three, two, one,
# Nearest to one: two, six, four, seven, three, five, eight, nine,
# Nearest to i: we, you, ii, g, changeover, x, t, preview,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to are: were, is, have, although, these, while, including, was,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Average loss at step 62000: 3.422394
# Average loss at step 64000: 3.370173
# Average loss at step 66000: 3.387106
# Average loss at step 68000: 3.304985
# Average loss at step 70000: 3.378670
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to on: upon, through, in, determinant, eigenvalue, misty, enola, cares,
# Nearest to years: days, months, year, hours, decades, weeks, times, minutes,
# Nearest to see: include, but, references, cronje, lat, refer, literally, borrower,
# Nearest to was: is, had, were, has, became, being, been, although,
# Nearest to who: he, they, which, arleigh, that, never, dogg, aggadah,
# Nearest to history: list, accuracy, fujitsu, populous, gospel, conses, philosophy, enemies,
# Nearest to zero: five, four, six, eight, seven, three, nine, two,
# Nearest to these: those, many, several, various, some, such, both, which,
# Nearest to more: less, very, most, too, smaller, hearted, rather, programmers,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to one: six, two, seven, eight, four, three, nine, five,
# Nearest to i: we, you, ii, g, they, t, preview, swnts,
# Nearest to four: six, five, eight, seven, three, two, nine, zero,
# Nearest to are: were, is, have, be, include, furigana, tentatively, accede,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Average loss at step 72000: 3.404088
# Average loss at step 74000: 3.434074
# Average loss at step 76000: 3.420618
# Average loss at step 78000: 3.371686
# Average loss at step 80000: 3.372389
# Nearest to five: seven, eight, four, three, six, nine, zero, two,
# Nearest to on: upon, under, determinant, through, against, estrada, in, enola,
# Nearest to years: days, months, year, hours, decades, minutes, weeks, centuries,
# Nearest to see: but, include, cronje, contends, refer, references, list, reorganization,
# Nearest to was: is, had, became, were, has, been, be, hertz,
# Nearest to who: he, which, arleigh, contraceptives, they, often, never, also,
# Nearest to history: list, accuracy, philosophy, allosaurus, gospel, populous, see, fragrant,
# Nearest to zero: five, eight, seven, four, six, three, nine, two,
# Nearest to these: many, several, those, some, various, which, both, examples,
# Nearest to more: less, most, very, smaller, rather, too, larger, highly,
# Nearest to seven: five, eight, nine, six, four, three, two, zero,
# Nearest to one: seven, eight, six, two, nine, three, four, five,
# Nearest to i: ii, we, you, g, t, they, iv, vi,
# Nearest to four: five, three, seven, eight, six, two, nine, zero,
# Nearest to are: were, is, have, include, be, those, although, mails,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Average loss at step 82000: 3.384667
# Average loss at step 84000: 3.303836
# Average loss at step 86000: 3.352518
# Average loss at step 88000: 3.333247
# Average loss at step 90000: 3.288458
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to on: upon, through, in, under, unambiguously, around, igf, during,
# Nearest to years: days, months, year, decades, hours, weeks, minutes, centuries,
# Nearest to see: references, list, ot, cronje, include, classify, jeffrey, stockade,
# Nearest to was: is, became, were, had, has, been, being, did,
# Nearest to who: he, arleigh, never, also, contraceptives, she, aggadah, bilayer,
# Nearest to history: list, regolith, geography, gospel, accuracy, conses, philosophy, populous,
# Nearest to zero: five, four, six, eight, seven, three, two, nine,
# Nearest to these: many, some, those, several, various, were, both, their,
# Nearest to more: less, most, very, rather, larger, particularly, too, highly,
# Nearest to seven: eight, six, nine, four, five, three, zero, one,
# Nearest to one: seven, four, two, six, three, five, eight, nine,
# Nearest to i: ii, we, you, t, iv, g, preview, galleys,
# Nearest to four: six, three, five, seven, eight, nine, zero, two,
# Nearest to are: were, have, is, these, be, although, accede, while,
# Nearest to eight: seven, nine, four, six, five, three, zero, one,
# Average loss at step 92000: 3.367938
# Average loss at step 94000: 3.344223
# Average loss at step 96000: 3.315729
# Average loss at step 98000: 3.413658
# Average loss at step 100000: 3.328249
# Nearest to five: seven, four, eight, six, three, zero, nine, two,
# Nearest to on: upon, in, around, through, about, proust, within, at,
# Nearest to years: days, months, year, decades, weeks, hours, minutes, times,
# Nearest to see: references, list, include, can, dinoflagellates, consider, refer, called,
# Nearest to was: is, were, became, had, being, has, been, remains,
# Nearest to who: he, often, arleigh, they, contraceptives, never, she, which,
# Nearest to history: list, gospel, philosophy, regolith, calculation, subject, development, origins,
# Nearest to zero: five, seven, eight, four, six, three, two, nine,
# Nearest to these: many, those, several, some, such, all, which, their,
# Nearest to more: less, very, rather, most, larger, smaller, too, quite,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to one: three, two, four, five, six, seven, eight, nine,
# Nearest to i: ii, you, we, g, t, iv, preview, nad,
# Nearest to four: five, eight, seven, three, six, two, nine, zero,
# Nearest to are: were, have, is, include, those, accede, require, be,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size,2*skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    words=[w for c,w in enumerate(buffer) if c!=target]
    batch[i]=words
    labels[i]=buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[bi] for bi in cw] for cw in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.zeros([batch_size, embedding_size])
  for i in range(2*skip_window):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.605048
# Nearest to may: chaldean, defense, allan, helix, guillaume, verrocchio, sped, sundarbans,
# Nearest to these: aphids, wicked, unix, writes, scarface, slapped, juries, electric,
# Nearest to new: fewest, quicker, buckinghamshire, eubulides, talents, harriman, oda, grit,
# Nearest to six: abolishes, futurist, unorganized, tightly, maritimes, kanji, borrows, xps,
# Nearest to there: purporting, itanium, libre, outburst, unbridled, menelaus, jealousy, processors,
# Nearest to of: colin, accommodates, etiquette, bloom, pfp, elaine, castes, noticing,
# Nearest to for: interrupting, winger, upto, moulton, nsdap, stripping, fudge, latinos,
# Nearest to in: sabina, aki, gal, canarian, schwartz, shrewsbury, lionel, ossie,
# Nearest to than: unpublished, coliseum, kodansha, dystopia, drinkers, painter, disulfide, sundance,
# Nearest to two: patrice, viceroy, distribution, publically, tetrachloride, tuple, isaak, necessitates,
# Nearest to one: zulus, tats, heizei, gays, shuttles, brassiere, jt, alen,
# Nearest to if: disproven, hitchens, vickers, deliberation, monochromatic, ideologically, surmounted, oscilloscope,
# Nearest to state: lauderdale, opencyc, blunder, hast, qualcomm, globemaster, nafta, kabuki,
# Nearest to only: built, gaze, flowed, bung, original, inputs, defies, marshes,
# Nearest to called: daiko, laurentiis, calculus, mosquitos, wessex, contextual, reverend, microwave,
# Nearest to they: scotland, obstinate, jon, impedes, afghans, sharm, differs, nbs,
# Average loss at step 2000: 4.093785
# Average loss at step 4000: 3.561306
# Average loss at step 6000: 3.383994
# Average loss at step 8000: 3.244700
# Average loss at step 10000: 3.178632
# Nearest to may: can, would, will, could, allan, mandolin, chaldean, should,
# Nearest to these: all, many, scarface, tempering, such, surpassed, resignations, swap,
# Nearest to new: boulevard, talents, fewest, prepares, dato, kingpin, silicone, amerigo,
# Nearest to six: eight, nine, five, seven, four, three, zero, two,
# Nearest to there: they, it, usually, pxe, recordings, antiderivatives, libre, plebs,
# Nearest to of: in, graces, cyclonic, editing, colin, gy, gow, for,
# Nearest to for: in, incidental, thane, from, through, of, as, after,
# Nearest to in: on, at, during, for, megadeth, coolest, of, from,
# Nearest to than: or, kodansha, unpublished, coliseum, towards, improves, disulfide, soloist,
# Nearest to two: four, three, five, eight, seven, nine, one, six,
# Nearest to one: two, four, nine, eight, three, seven, five, six,
# Nearest to if: lollard, when, monochromatic, referees, bandage, vickers, portillo, oscilloscope,
# Nearest to state: blender, globemaster, natural, nafta, rerio, lauderdale, kabuki, qualcomm,
# Nearest to only: attendants, aegon, gaze, necessitating, horkheimer, dribbling, helios, ami,
# Nearest to called: tinbergen, wessex, ppc, perpetrator, directive, zachary, calculus, laurentiis,
# Nearest to they: he, we, there, it, she, dug, who, you,
# Average loss at step 12000: 3.202490
# Average loss at step 14000: 3.157360
# Average loss at step 16000: 3.178517
# Average loss at step 18000: 3.121457
# Average loss at step 20000: 2.991844
# Nearest to may: can, would, will, could, should, must, might, shall,
# Nearest to these: many, such, some, they, resignations, which, several, there,
# Nearest to new: kingpin, predictably, titanic, musculus, prototypical, single, havana, dato,
# Nearest to six: seven, five, eight, four, nine, three, zero, two,
# Nearest to there: they, it, usually, he, often, which, dresses, these,
# Nearest to of: impractical, in, adrien, poaching, graces, pinter, for, phonemically,
# Nearest to for: presenting, fraser, incidental, admirals, of, when, after, cheerful,
# Nearest to in: at, on, during, of, throughout, pendergast, since, nonpartisan,
# Nearest to than: or, kodansha, coliseum, soloist, dzhokhar, much, towards, chromaticity,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to one: seven, two, four, six, eight, five, nine, three,
# Nearest to if: when, lollard, though, where, referees, whispered, monochromatic, bandage,
# Nearest to state: government, blender, nafta, opencyc, rerio, kabuki, qualcomm, lut,
# Nearest to only: aegon, guanosine, ibanez, stupa, commenting, horkheimer, attendants, helios,
# Nearest to called: tinbergen, used, sephiroth, wessex, fuses, sculpture, rpr, directive,
# Nearest to they: we, there, he, you, it, she, dug, these,
# Average loss at step 22000: 3.074098
# Average loss at step 24000: 3.041099
# Average loss at step 26000: 2.998049
# Average loss at step 28000: 3.031742
# Average loss at step 30000: 3.004942
# Nearest to may: can, would, could, will, should, must, might, does,
# Nearest to these: such, many, some, they, those, both, there, all,
# Nearest to new: inches, musculus, kingpin, dato, havana, commutator, predictably, strains,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to there: they, it, he, she, usually, these, sometimes, still,
# Nearest to of: in, impractical, cyclonic, phonemically, emitter, pepin, concerning, including,
# Nearest to for: including, fraser, in, incidental, presenting, eln, gmc, if,
# Nearest to in: during, within, of, since, pendergast, on, among, from,
# Nearest to than: kodansha, or, much, soloist, dzhokhar, emigrated, chromaticity, congratulations,
# Nearest to two: three, six, four, five, eight, seven, nine, one,
# Nearest to one: two, five, three, four, six, seven, nine, eight,
# Nearest to if: when, though, lollard, before, where, boring, whispered, after,
# Nearest to state: lut, blender, government, states, opencyc, nafta, barter, viruses,
# Nearest to only: aegon, births, ibanez, always, stupa, daewoo, dudley, xserve,
# Nearest to called: tinbergen, used, fuses, rpr, named, gimel, sephiroth, sculpture,
# Nearest to they: we, there, you, he, she, these, it, typically,
# Average loss at step 32000: 2.819967
# Average loss at step 34000: 2.952690
# Average loss at step 36000: 2.943807
# Average loss at step 38000: 2.940141
# Average loss at step 40000: 2.933411
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to these: those, such, many, various, both, resignations, several, some,
# Nearest to new: inches, musculus, kingpin, libertine, prototypical, predictably, closing, strains,
# Nearest to six: eight, seven, five, four, three, nine, two, zero,
# Nearest to there: they, it, he, typically, she, usually, sometimes, we,
# Nearest to of: colin, cyclonic, adrien, concerning, for, although, nnrot, cmos,
# Nearest to for: after, cams, of, ugandan, when, thane, presenting, gmc,
# Nearest to in: during, within, among, delft, until, primetime, nonpartisan, throughout,
# Nearest to than: while, but, soloist, kodansha, much, or, dzhokhar, momenta,
# Nearest to two: three, six, five, four, seven, eight, one, nine,
# Nearest to one: two, seven, three, six, five, eight, four, nine,
# Nearest to if: when, though, before, where, lollard, boring, after, since,
# Nearest to state: blender, government, nafta, states, city, algorithmic, lut, biscuits,
# Nearest to only: stupa, births, aegon, oratory, first, mapped, always, ibanez,
# Nearest to called: named, tinbergen, considered, fuses, known, dormitories, enchanted, used,
# Nearest to they: we, he, there, you, she, it, typically, i,
# Average loss at step 42000: 2.954245
# Average loss at step 44000: 2.957147
# Average loss at step 46000: 2.907294
# Average loss at step 48000: 2.862644
# Average loss at step 50000: 2.845780
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to these: many, those, several, some, various, such, all, their,
# Nearest to new: inches, predictably, musculus, modern, borland, dato, boat, titanic,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to there: they, it, he, we, she, typically, usually, generally,
# Nearest to of: in, concerning, nnrot, phonemically, graces, diz, gy, colin,
# Nearest to for: when, if, ipx, shortstop, while, gard, including, fraser,
# Nearest to in: during, within, at, from, on, of, near, until,
# Nearest to than: much, kodansha, or, momenta, botanicals, soloist, yielding, phosphates,
# Nearest to two: three, four, six, eight, seven, five, nine, one,
# Nearest to one: two, seven, four, eight, nine, six, three, five,
# Nearest to if: when, though, where, before, while, since, because, lollard,
# Nearest to state: blender, government, states, nafta, lut, smoky, city, barter,
# Nearest to only: no, even, actually, always, otherwise, still, births, not,
# Nearest to called: named, used, considered, tinbergen, known, enchanted, fuses, placed,
# Nearest to they: we, there, he, you, she, it, bund, typically,
# Average loss at step 52000: 2.884429
# Average loss at step 54000: 2.862522
# Average loss at step 56000: 2.855938
# Average loss at step 58000: 2.752650
# Average loss at step 60000: 2.827442
# Nearest to may: can, could, must, would, will, should, might, cannot,
# Nearest to these: such, those, several, many, various, some, certain, arousing,
# Nearest to new: dato, old, predictably, inches, modern, fewest, ducal, thrace,
# Nearest to six: seven, five, four, nine, eight, three, two, zero,
# Nearest to there: they, it, still, he, she, usually, we, generally,
# Nearest to of: phonemically, applicative, concerning, cochran, graces, including, nnrot, include,
# Nearest to for: without, thane, after, ipx, when, before, incidental, fraser,
# Nearest to in: during, within, at, among, from, throughout, orf, on,
# Nearest to than: or, cimmerian, kodansha, even, shamash, while, soloist, dzhokhar,
# Nearest to two: three, four, one, six, five, seven, eight, nine,
# Nearest to one: two, four, seven, five, eight, six, nine, three,
# Nearest to if: when, though, where, after, lollard, although, before, while,
# Nearest to state: states, nafta, barter, government, lut, kabuki, reportage, policing,
# Nearest to only: otherwise, always, actually, evade, either, ductus, generally, usually,
# Nearest to called: named, considered, used, known, tinbergen, fuses, declares, defined,
# Nearest to they: we, he, you, there, she, it, these, typically,
# Average loss at step 62000: 2.826912
# Average loss at step 64000: 2.771687
# Average loss at step 66000: 2.762902
# Average loss at step 68000: 2.717722
# Average loss at step 70000: 2.779842
# Nearest to may: must, should, could, can, might, will, would, cannot,
# Nearest to these: those, some, several, numerous, various, many, they, both,
# Nearest to new: different, modern, havana, dato, boopsie, closing, collectivized, separate,
# Nearest to six: eight, five, seven, nine, four, three, two, zero,
# Nearest to there: they, it, still, he, she, sometimes, we, typically,
# Nearest to of: including, in, nnrot, for, cyclonic, concerning, despite, gy,
# Nearest to for: after, during, thane, of, in, fraser, ipx, curfew,
# Nearest to in: during, within, throughout, under, at, on, since, of,
# Nearest to than: even, kodansha, cimmerian, soloist, or, codebreaking, regained, reputable,
# Nearest to two: three, four, seven, six, five, eight, one, nine,
# Nearest to one: two, seven, three, six, five, eight, nine, four,
# Nearest to if: when, though, before, where, lollard, since, after, because,
# Nearest to state: government, states, nafta, barter, lut, churchyard, kabuki, transition,
# Nearest to only: even, births, andrade, actually, cpu, ibanez, dek, aegon,
# Nearest to called: named, known, tinbergen, considered, gimel, referred, titled, fuses,
# Nearest to they: we, he, you, there, she, it, these, typically,
# Average loss at step 72000: 2.793259
# Average loss at step 74000: 2.651190
# Average loss at step 76000: 2.801603
# Average loss at step 78000: 2.825838
# Average loss at step 80000: 2.776355
# Nearest to may: might, can, could, should, must, would, will, cannot,
# Nearest to these: those, some, several, both, many, which, they, certain,
# Nearest to new: different, dato, inches, old, musculus, ducal, previous, openings,
# Nearest to six: seven, eight, five, nine, four, three, two, zero,
# Nearest to there: they, it, we, he, typically, sometimes, still, she,
# Nearest to of: in, concerning, colin, cyclonic, monumental, despite, nnrot, and,
# Nearest to for: when, after, without, thane, chambered, while, including, ipx,
# Nearest to in: during, within, at, throughout, on, under, from, near,
# Nearest to than: or, kodansha, even, much, cimmerian, yielding, soloist, congratulations,
# Nearest to two: three, four, six, one, five, eight, seven, nine,
# Nearest to one: two, seven, three, four, eight, six, five, nine,
# Nearest to if: when, though, where, lollard, before, since, plenipotentiary, transduction,
# Nearest to state: states, government, lut, barter, nafta, churchyard, quadrature, reportage,
# Nearest to only: actually, even, either, births, xserve, already, hco, oldest,
# Nearest to called: named, known, gimel, titled, considered, tinbergen, referred, dormitories,
# Nearest to they: we, you, he, there, she, i, it, these,
# Average loss at step 82000: 2.664984
# Average loss at step 84000: 2.768980
# Average loss at step 86000: 2.733861
# Average loss at step 88000: 2.754934
# Average loss at step 90000: 2.736986
# Nearest to may: might, must, should, can, could, would, will, cannot,
# Nearest to these: those, such, some, several, they, various, many, both,
# Nearest to new: old, collectivized, erupt, inches, musculus, dato, closing, modern,
# Nearest to six: eight, seven, five, nine, four, three, two, zero,
# Nearest to there: they, it, he, she, still, we, typically, sometimes,
# Nearest to of: concerning, despite, regarding, nnrot, indicating, applicative, mikhailovich, undercover,
# Nearest to for: cams, thane, after, without, ipx, gard, despite, when,
# Nearest to in: within, during, on, throughout, at, near, under, delft,
# Nearest to than: kodansha, or, even, cimmerian, hugging, norodom, phosphates, much,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to one: two, four, six, eight, seven, nine, three, five,
# Nearest to if: when, though, before, where, lollard, since, plenipotentiary, until,
# Nearest to state: government, states, nafta, blender, national, watering, reportage, barter,
# Nearest to only: either, last, actually, always, xserve, births, no, oldest,
# Nearest to called: named, known, considered, described, titled, referred, gimel, used,
# Nearest to they: we, you, there, he, she, i, it, these,
# Average loss at step 92000: 2.679165
# Average loss at step 94000: 2.725631
# Average loss at step 96000: 2.699341
# Average loss at step 98000: 2.366843
# Average loss at step 100000: 2.403029
# Nearest to may: might, could, must, should, would, can, will, cannot,
# Nearest to these: those, several, such, some, certain, many, there, examples,
# Nearest to new: old, erupt, collectivized, dziga, musculus, modern, fifth, prototypical,
# Nearest to six: eight, seven, nine, five, four, three, two, zero,
# Nearest to there: they, it, he, she, still, sometimes, we, generally,
# Nearest to of: despite, nnrot, cyclonic, in, cochran, including, rancher, concerning,
# Nearest to for: after, during, thane, against, by, if, when, cams,
# Nearest to in: during, at, within, near, throughout, of, on, nanosystems,
# Nearest to than: or, kodansha, misinformation, much, even, least, cimmerian, hugging,
# Nearest to two: three, four, five, six, eight, seven, nine, one,
# Nearest to one: two, three, six, seven, five, four, nine, eight,
# Nearest to if: when, though, before, follows, after, where, lollard, plenipotentiary,
# Nearest to state: states, government, nafta, churchyard, begging, defence, national, watering,
# Nearest to only: either, last, births, dek, rpp, wallis, aegon, probably,
# Nearest to called: named, referred, titled, used, see, played, tornadoes, known,
# Nearest to they: we, he, there, you, she, i, it, who,
