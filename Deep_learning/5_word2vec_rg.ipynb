# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'of', 'as', 'term']

# %%
data_index = 0

def generate_batch_cbow(batch_size, skip_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2*skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    context = [w for c, w in enumerate(buffer) if c != target]
    batch[i] = context
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[bi] for bi in cw] for cw in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(2*skip_window):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    
    
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, skip_window)
    #batch_data, batch_labels = generate_batch(
    #  batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.512296
# Nearest to or: bavaria, nashville, poets, creator, akron, immunities, wire, heiner,
# Nearest to d: attend, orbiting, rescheduled, battleground, conn, lego, rabban, hierarchies,
# Nearest to for: fives, tunnel, remit, benno, factor, lonergan, anniversary, timur,
# Nearest to he: diglossia, educators, shareholder, cater, astrophysics, glittering, homophony, algeria,
# Nearest to no: corr, centrepiece, airflow, trickle, translate, entry, sulfide, morpork,
# Nearest to some: lithography, grandmasters, pesticides, bartolomeo, erstwhile, keitai, serfdom, buckwheat,
# Nearest to than: precludes, mises, nourished, tunnels, reminding, pitcher, heligoland, pipe,
# Nearest to to: intervals, mede, eleazar, launcher, rodin, israeli, melissa, hagelin,
# Nearest to however: mutable, refineries, parasites, enosis, theologically, formal, broker, falling,
# Nearest to his: announcing, subterfuge, cavalrymen, rein, jogaila, rgb, rising, dioscorus,
# Nearest to people: adler, mez, naka, resignations, udma, suit, elfin, anonymity,
# Nearest to one: wiping, actionscript, kidnappings, mikael, yag, birding, romanian, revenge,
# Nearest to which: consistently, elgar, corrado, superpowered, colchester, robo, papacy, regular,
# Nearest to after: transcripts, dirac, rinse, ortelius, adherents, oneworld, fingertips, nostrand,
# Nearest to during: frenchmen, ismail, planing, childhood, solemnity, gallop, pushing, torment,
# Nearest to is: elixir, clears, renouncing, arming, appreciative, polyglot, lyne, socony,
# Average loss at step 2000: 4.108502
# Average loss at step 4000: 3.556220
# Average loss at step 6000: 3.389124
# Average loss at step 8000: 3.240605
# Average loss at step 10000: 3.173866
# Nearest to or: and, than, fandoms, xp, technically, appended, johns, siona,
# Nearest to d: b, haag, schottky, penile, wearer, conn, inductee, rescheduled,
# Nearest to for: by, as, darmstadt, with, reintroduction, exporting, pairwise, portal,
# Nearest to he: it, they, she, who, there, fictionalized, medium, advert,
# Nearest to no: misleadingly, translate, trickle, midwestern, airflow, saga, scot, centrepiece,
# Nearest to some: many, these, fergana, any, marquee, several, most, pesticides,
# Nearest to than: or, xp, precludes, pipe, olympians, reminding, nourished, enlisted,
# Nearest to to: would, hazel, should, could, will, can, mede, not,
# Nearest to however: but, refineries, mutable, gnutella, basic, that, sparingly, although,
# Nearest to his: their, her, its, the, my, this, annexation, marquee,
# Nearest to people: those, bold, summarised, elmer, livers, kept, galba, experiences,
# Nearest to one: eight, two, four, six, three, huts, abduction, statistical,
# Nearest to which: that, this, it, but, who, never, what, also,
# Nearest to after: before, perfect, spectrometer, as, ortelius, lemass, nostrand, dirac,
# Nearest to during: in, frenchmen, crystallographic, following, gallop, stenella, planing, hamas,
# Nearest to is: was, are, has, patchy, became, cook, be, were,
# Average loss at step 12000: 3.199545
# Average loss at step 14000: 3.153204
# Average loss at step 16000: 3.175461
# Average loss at step 18000: 3.125400
# Average loss at step 20000: 2.986206
# Nearest to or: and, than, appended, valine, et, nchen, myocardial, tenzin,
# Nearest to d: b, penile, schottky, inductee, haag, tensile, posthumously, conn,
# Nearest to for: apocryphal, tangerine, lieben, oshii, muonium, accommodations, phishing, seamless,
# Nearest to he: she, it, they, who, there, then, i, eventually,
# Nearest to no: dogmatic, every, any, misleadingly, scot, musab, fugitive, a,
# Nearest to some: many, these, several, most, fergana, this, all, any,
# Nearest to than: or, xp, pipe, broome, olympians, earnest, precludes, enlisted,
# Nearest to to: homemade, fountainhead, would, amidst, can, ingham, flipper, rodin,
# Nearest to however: but, although, that, while, brady, though, where, americanization,
# Nearest to his: their, her, its, my, the, our, whose, citizenship,
# Nearest to people: those, erne, milano, experiences, kitchener, others, award, jews,
# Nearest to one: two, six, seven, eight, four, five, hurtful, figurehead,
# Nearest to which: that, this, also, often, it, there, who, spice,
# Nearest to after: before, when, perfect, since, during, from, contraception, exegesis,
# Nearest to during: when, upon, through, hamas, in, within, crystallographic, on,
# Nearest to is: was, are, became, has, does, kinematic, makes, contains,
# Average loss at step 22000: 3.075812
# Average loss at step 24000: 3.033107
# Average loss at step 26000: 2.995696
# Average loss at step 28000: 3.025860
# Average loss at step 30000: 3.005362
# Nearest to or: and, than, xp, minimi, siona, jargon, skaters, but,
# Nearest to d: b, inductee, tensile, xvi, prominently, haag, penile, ineffective,
# Nearest to for: heian, cowes, darmstadt, seamless, mandaeanism, cleve, engravers, ryukyu,
# Nearest to he: she, it, they, there, who, fictionalized, never, eventually,
# Nearest to no: any, sil, unmodified, scot, fugitive, gokturk, every, dogmatic,
# Nearest to some: many, several, these, any, all, various, most, certain,
# Nearest to than: or, xp, but, pipe, broome, jail, earnest, olympians,
# Nearest to to: can, would, mede, could, hazel, homemade, will, must,
# Nearest to however: but, although, though, that, while, which, consider, arouse,
# Nearest to his: her, their, my, its, your, our, the, marquee,
# Nearest to people: erne, milano, men, others, players, those, experiences, americans,
# Nearest to one: two, five, six, three, four, seven, manchuria, hurtful,
# Nearest to which: that, this, what, also, however, who, thea, still,
# Nearest to after: before, when, during, through, perfect, since, under, despite,
# Nearest to during: in, after, under, when, before, harps, until, at,
# Nearest to is: was, are, has, became, contains, becomes, be, indicating,
# Average loss at step 32000: 2.828971
# Average loss at step 34000: 2.951905
# Average loss at step 36000: 2.941397
# Average loss at step 38000: 2.945619
# Average loss at step 40000: 2.928595
# Nearest to or: and, archdukes, while, than, et, milken, but, appended,
# Nearest to d: b, inductee, battleground, herbal, municipalities, prominently, haag, h,
# Nearest to for: chesterfield, aquaria, dactylic, emotive, munro, cowes, of, nuh,
# Nearest to he: she, it, they, there, who, we, this, dreamer,
# Nearest to no: any, unmodified, dogmatic, belatedly, sil, gokturk, breathy, misleadingly,
# Nearest to some: many, several, various, most, these, all, any, certain,
# Nearest to than: but, much, pipe, broome, or, far, xp, enlisted,
# Nearest to to: will, would, can, adret, horrendous, could, hazel, roundhouse,
# Nearest to however: but, though, although, while, that, when, consider, perceived,
# Nearest to his: her, their, my, its, your, our, the, acupuncture,
# Nearest to people: men, women, erne, children, players, jews, others, milano,
# Nearest to one: two, seven, hurtful, three, six, quaternion, eight, five,
# Nearest to which: this, that, also, what, who, seminar, where, homeomorphic,
# Nearest to after: before, during, when, while, tolerances, ebu, despite, from,
# Nearest to during: in, after, before, through, throughout, when, within, until,
# Nearest to is: was, has, are, became, makes, be, requires, remains,
# Average loss at step 42000: 2.948253
# Average loss at step 44000: 2.961146
# Average loss at step 46000: 2.906066
# Average loss at step 48000: 2.870243
# Average loss at step 50000: 2.845410
# Nearest to or: and, than, nchen, xp, sparkle, keillor, archdukes, appended,
# Nearest to d: b, schottky, inductee, stubby, haag, myositis, endothermy, conn,
# Nearest to for: seamless, dactylic, oshii, while, although, darmstadt, chesterfield, heian,
# Nearest to he: she, it, they, there, who, we, numan, frustrated,
# Nearest to no: any, only, unmodified, gokturk, partitioned, belatedly, she, spiegel,
# Nearest to some: many, several, these, most, any, certain, all, various,
# Nearest to than: or, broome, pipe, syndicate, xp, judaean, olympians, much,
# Nearest to to: will, besson, tensor, hagelin, should, could, shall, hazel,
# Nearest to however: although, but, that, though, while, especially, consider, mummies,
# Nearest to his: her, their, its, my, your, our, the, whose,
# Nearest to people: jews, men, players, women, christians, children, americans, erne,
# Nearest to one: two, four, seven, six, eight, quaternion, foreseen, twenty,
# Nearest to which: that, what, this, also, these, it, where, who,
# Nearest to after: before, when, during, while, despite, without, until, since,
# Nearest to during: in, after, within, before, throughout, until, despite, when,
# Nearest to is: was, has, are, does, contains, includes, remains, becomes,
# Average loss at step 52000: 2.892813
# Average loss at step 54000: 2.865122
# Average loss at step 56000: 2.861398
# Average loss at step 58000: 2.747836
# Average loss at step 60000: 2.831295
# Nearest to or: and, than, rocketry, appended, siona, saber, deteriorated, et,
# Nearest to d: b, j, schottky, cassava, xvi, inductee, h, hilaire,
# Nearest to for: against, without, darmstadt, heian, after, mcs, cleve, vardar,
# Nearest to he: she, it, they, who, there, we, i, eventually,
# Nearest to no: any, spiegel, sil, partitioned, misleadingly, fugitive, breathy, unmodified,
# Nearest to some: many, several, any, these, most, all, certain, each,
# Nearest to than: or, broome, xp, even, much, olympians, berengar, syndicate,
# Nearest to to: could, hazel, should, homemade, would, will, horrendous, must,
# Nearest to however: but, although, while, though, that, sever, when, which,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to people: women, jews, children, men, americans, christians, players, writers,
# Nearest to one: two, six, seven, four, three, eight, five, nine,
# Nearest to which: that, what, this, who, thea, also, usually, it,
# Nearest to after: before, during, when, while, if, despite, without, following,
# Nearest to during: in, after, within, under, before, at, when, until,
# Nearest to is: was, has, are, requires, does, becomes, remains, seems,
# Average loss at step 62000: 2.828370
# Average loss at step 64000: 2.777529
# Average loss at step 66000: 2.764743
# Average loss at step 68000: 2.715046
# Average loss at step 70000: 2.792921
# Nearest to or: and, than, archdukes, appended, nchen, gridiron, jt, marcellinus,
# Nearest to d: b, schottky, stylist, guangdong, stockhausen, ulein, penile, technetium,
# Nearest to for: against, cowes, provably, heian, including, despite, lieben, if,
# Nearest to he: she, it, they, who, we, there, eventually, finally,
# Nearest to no: any, kk, spiegel, dragoons, sil, dogmatic, turquoise, fugitive,
# Nearest to some: many, several, certain, these, any, various, most, attribution,
# Nearest to than: or, olympians, aboard, broome, much, burundian, raions, but,
# Nearest to to: hazel, would, will, should, could, amidst, must, mboxx,
# Nearest to however: but, although, though, while, that, since, except, scarce,
# Nearest to his: her, their, its, my, your, the, our, whose,
# Nearest to people: women, men, children, jews, americans, writers, person, christians,
# Nearest to one: two, seven, three, six, five, hurtful, fact, eight,
# Nearest to which: that, this, also, what, usually, who, teleology, landmines,
# Nearest to after: before, during, when, while, despite, until, following, without,
# Nearest to during: after, in, under, within, throughout, when, before, until,
# Nearest to is: was, has, contains, became, remains, are, makes, becomes,
# Average loss at step 72000: 2.795551
# Average loss at step 74000: 2.645742
# Average loss at step 76000: 2.798229
# Average loss at step 78000: 2.825989
# Average loss at step 80000: 2.782817
# Nearest to or: and, than, et, valine, sparkle, appended, etc, gridiron,
# Nearest to d: b, l, xvi, j, f, posthumously, ptolemy, te,
# Nearest to for: including, after, vardar, heian, during, when, mandaeanism, without,
# Nearest to he: she, it, they, there, who, we, once, originally,
# Nearest to no: any, partitioned, dogmatic, pynchon, spiegel, only, sil, unmodified,
# Nearest to some: many, several, certain, these, any, various, few, this,
# Nearest to than: or, much, aboard, olympians, buffers, mongoloid, burundian, destry,
# Nearest to to: will, would, mede, cannot, can, mboxx, homemade, must,
# Nearest to however: but, although, though, that, since, while, soon, needed,
# Nearest to his: her, their, your, my, its, our, whose, personal,
# Nearest to people: men, women, americans, children, writers, jews, christians, persons,
# Nearest to one: two, four, seven, three, six, eight, five, lw,
# Nearest to which: that, what, this, who, also, teleology, landmines, typically,
# Nearest to after: before, during, despite, while, when, without, following, for,
# Nearest to during: in, after, until, throughout, before, under, when, despite,
# Nearest to is: was, are, becomes, has, contains, remains, includes, makes,
# Average loss at step 82000: 2.664944
# Average loss at step 84000: 2.769551
# Average loss at step 86000: 2.738312
# Average loss at step 88000: 2.751502
# Average loss at step 90000: 2.730614
# Nearest to or: and, than, versus, though, tenzin, appended, but, shing,
# Nearest to d: b, l, j, ptolemy, f, xvi, cytosol, n,
# Nearest to for: heian, including, mandaeanism, provably, darmstadt, lieben, vardar, engravers,
# Nearest to he: she, it, they, there, we, who, massoud, originally,
# Nearest to no: any, little, spiegel, unmodified, partitioned, dogmatic, strong, sil,
# Nearest to some: many, several, certain, any, most, various, this, each,
# Nearest to than: or, even, buffers, susceptible, broome, olympians, aboard, mongoloid,
# Nearest to to: must, should, homemade, mboxx, tomahawk, might, cannot, would,
# Nearest to however: but, although, though, that, especially, babbitt, consider, soon,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to people: women, men, jews, americans, children, users, individuals, christians,
# Nearest to one: two, six, four, eight, seven, three, teosinte, nine,
# Nearest to which: what, this, that, actually, who, typically, also, thea,
# Nearest to after: before, during, despite, when, afterwards, while, if, without,
# Nearest to during: after, in, throughout, within, before, at, until, despite,
# Nearest to is: was, has, are, remains, became, becomes, contains, seems,
# Average loss at step 92000: 2.679047
# Average loss at step 94000: 2.728067
# Average loss at step 96000: 2.702592
# Average loss at step 98000: 2.364790
# Average loss at step 100000: 2.395023
# Nearest to or: and, than, appended, though, archdukes, heuristic, drang, jt,
# Nearest to d: b, guangdong, daggers, endothermy, decorate, blonde, schottky, joaquin,
# Nearest to for: after, heian, if, lieben, cleve, against, vardar, mcs,
# Nearest to he: she, they, it, there, who, we, numan, initially,
# Nearest to no: any, little, partitioned, spiegel, sil, pynchon, foreground, revolver,
# Nearest to some: many, several, certain, any, these, various, this, all,
# Nearest to than: or, much, even, buffers, ferrand, broome, destry, hindenburg,
# Nearest to to: would, must, should, mboxx, cannot, helped, will, towards,
# Nearest to however: but, although, though, that, since, especially, and, when,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to people: women, men, children, jews, americans, individuals, person, persons,
# Nearest to one: two, three, six, five, hurtful, teosinte, four, defaults,
# Nearest to which: that, what, this, actually, also, who, typically, overcrowded,
# Nearest to after: before, during, despite, when, without, afterwards, following, while,
# Nearest to during: in, after, under, at, despite, throughout, before, within,
# Nearest to is: was, has, remains, are, becomes, became, seems, represents,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
